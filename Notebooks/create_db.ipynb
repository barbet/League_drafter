# %%
# if on google collab
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/My Drive/Lol/data_collection')
import collect_data
data_path = '/content/drive/My Drive/Lol/data'

# %%
## else
# import collect_data
# data_path = '../data'

# %%
import images from website
collect_data.import_splashs_art(data_path)

# %%
# collect high elo ID
collect_data.import_summoners(data_path, verbose=1)

# %%
# collect high elo matchs ID
collect_data.import_matchs_id(data_path, verbose=1)

# %%
# collect high elo matchs stats
collect_data.import_matchs(data_path, verbose=1)
